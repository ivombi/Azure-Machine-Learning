# %% [markdown]
# ### Author: Kubam Ivo
# ### Date: 7/18/2020

# %% [markdown]
# In this tutorial, run your scikit-learn training scripts at enterprise scale by using the Azure Machine Learning SKlearn estimator class.
#
# The example scripts in this article are used to classify iris flower images to build a machine learning model based on scikit-learn's iris dataset.

# %%
# Importing packages

import os
import urllib
import shutil
import azureml

from azureml.core import Experiment
from azureml.core import Workspace, Run

from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# %%
# Initialising Workspace

ws = Workspace.from_config()

# %%
# Create a machine learning experiment

project_folder = './sklearn-iris'
os.makedirs(project_folder, exist_ok=True)

experiment = Experiment(workspace=ws,name='sklearn-iris')

# %%
# Importing script and dataset 
shutil.copy('./train_iris.py', project_folder)
shutil.copy('./iris',project_folder)
# Out:
# './sklearn-iris/iris'

# %%
# Create or get a compute target
cluster_name = "mlcompute"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2', 
                                                           max_nodes=4)

    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

    compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Found existing compute target

# %%
# Create a scikit -learn estimator
from azureml.train.sklearn import SKLearn

script_params = {
    '--kernel': 'linear',
    '--penalty': 1.0,
}

estimator = SKLearn(source_directory=project_folder, 
                    script_params=script_params,
                    compute_target=compute_target,
                    entry_script='train_iris.py',
                    pip_packages=['joblib==0.13.2']
                   )
# Out:
# WARNING - You have specified to install packages in your run. Note that you have overridden Azure ML's installation of the following packages: ['joblib']. We cannot guarantee image build will succeed.

# %%
# Submit a run
run = experiment.submit(estimator)
run.wait_for_completion(show_output=True)
# Out:
# RunId: sklearn-iris_1595146164_f6d591a1
# Web View: https://ml.azure.com/experiments/sklearn-iris/runs/sklearn-iris_1595146164_f6d591a1?wsid=/subscriptions/a1839f8e-ad8f-4825-ab97-e9628255f2bb/resourcegroups/azureml/workspaces/ml_practice
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2020/07/19 08:09:36 Downloading source code...
# 2020/07/19 08:09:37 Finished downloading source code
# 2020/07/19 08:09:37 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/07/19 08:09:38 Successfully set up Docker network: acb_default_network
# 2020/07/19 08:09:38 Setting up Docker configuration...
# 2020/07/19 08:09:38 Successfully set up Docker configuration
# 2020/07/19 08:09:38 Logging in to registry: mlpractice98dcf28c.azurecr.io
# 2020/07/19 08:09:39 Successfully logged into mlpractice98dcf28c.azurecr.io
# 2020/07/19 08:09:39 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/07/19 08:09:39 Scanning for dependencies...
# 2020/07/19 08:09:40 Successfully scanned dependencies
# 2020/07/19 08:09:40 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/14 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1@sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
# sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# fe703b657a32: Pulling fs layer
# f9df1fafd224: Pulling fs layer
# a645a4b887f9: Pulling fs layer
# 57db7fe0b522: Pulling fs layer
# 20b5fabe4f63: Pulling fs layer
# 22898513a7dc: Pulling fs layer
# b77f65fcd9d7: Pulling fs layer
# 132ebd5cd5ca: Pulling fs layer
# 01991399be72: Pulling fs layer
# 60c58ca14ef7: Pulling fs layer
# ca339bb1ce1b: Pulling fs layer
# b77f65fcd9d7: Waiting
# 132ebd5cd5ca: Waiting
# 01991399be72: Waiting
# 60c58ca14ef7: Waiting
# ca339bb1ce1b: Waiting
# 57db7fe0b522: Waiting
# 20b5fabe4f63: Waiting
# 22898513a7dc: Waiting
# f9df1fafd224: Verifying Checksum
# f9df1fafd224: Download complete
# a645a4b887f9: Verifying Checksum
# a645a4b887f9: Download complete
# 57db7fe0b522: Verifying Checksum
# 57db7fe0b522: Download complete
# fe703b657a32: Verifying Checksum
# fe703b657a32: Download complete
# b77f65fcd9d7: Verifying Checksum
# b77f65fcd9d7: Download complete
# fe703b657a32: Pull complete
# f9df1fafd224: Pull complete
# a645a4b887f9: Pull complete
# 57db7fe0b522: Pull complete
# 132ebd5cd5ca: Verifying Checksum
# 132ebd5cd5ca: Download complete
# 22898513a7dc: Verifying Checksum
# 22898513a7dc: Download complete
# 60c58ca14ef7: Verifying Checksum
# 60c58ca14ef7: Download complete
# ca339bb1ce1b: Verifying Checksum
# ca339bb1ce1b: Download complete
# 20b5fabe4f63: Download complete
# 01991399be72: Verifying Checksum
# 01991399be72: Download complete
# 20b5fabe4f63: Pull complete
# 22898513a7dc: Pull complete
# b77f65fcd9d7: Pull complete
# 132ebd5cd5ca: Pull complete
# 01991399be72: Pull complete
# 60c58ca14ef7: Pull complete
# ca339bb1ce1b: Pull complete
# Digest: sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1@sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
#  ---> a0dab4f7c804
# Step 2/14 : USER root
#  ---> Running in 62b3cdae5521
# Removing intermediate container 62b3cdae5521
#  ---> 2d9f8a4c6639
# Step 3/14 : RUN mkdir -p $HOME/.cache
#  ---> Running in 8c826218d1c5
# Removing intermediate container 8c826218d1c5
#  ---> bc49eac3a703
# Step 4/14 : WORKDIR /
#  ---> Running in 18df021a1b0a
# Removing intermediate container 18df021a1b0a
#  ---> 8bbb624128d2
# Step 5/14 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 787392124adc
# Step 6/14 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 1e254069e82e
# Removing intermediate container 1e254069e82e
#  ---> f82b1a981a86
# Step 7/14 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> f496cddc1634
# Step 8/14 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 7a035b2b9a56
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ####2      |  43%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# ca-certificates-2020 | 133 KB    |            |   0%
# ca-certificates-2020 | 133 KB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##8        |  29%
# python-3.6.2         | 27.0 MB   | ######5    |  66%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# wheel-0.34.2         | 49 KB     |            |   0%
# wheel-0.34.2         | 49 KB     | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# pip-20.1.1           | 2.0 MB    |            |   0%
# pip-20.1.1           | 2.0 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# setuptools-49.2.0    | 929 KB    |            |   0%
# setuptools-49.2.0    | 929 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.zdj6ybrd.requirements.txt']
# Pip subprocess output:
# Collecting joblib==0.13.2
#   Downloading joblib-0.13.2-py2.py3-none-any.whl (278 kB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.9.0-py3-none-any.whl (3.0 kB)
# Collecting scikit-learn==0.20.3
#   Downloading scikit_learn-0.20.3-cp36-cp36m-manylinux1_x86_64.whl (5.4 MB)
# Collecting scipy==1.2.1
#   Downloading scipy-1.2.1-cp36-cp36m-manylinux1_x86_64.whl (24.8 MB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azureml-core~=1.9.0
#   Downloading azureml_core-1.9.0-py3-none-any.whl (1.5 MB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting azureml-dataprep[fuse]<1.10.0a,>=1.9.0a
#   Downloading azureml_dataprep-1.9.3-py3-none-any.whl (27.7 MB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting numpy>=1.8.2
#   Downloading numpy-1.19.0-cp36-cp36m-manylinux2010_x86_64.whl (14.6 MB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting docker
#   Downloading docker-4.2.2-py2.py3-none-any.whl (144 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-10.1.0-py2.py3-none-any.whl (892 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.4-py2.py3-none-any.whl (55 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.17-py2.py3-none-any.whl (84 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting pytz
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting ruamel.yaml>0.16.7
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting azure-mgmt-network~=10.0
#   Downloading azure_mgmt_network-10.2.0-py2.py3-none-any.whl (8.6 MB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-11.1.0-py2.py3-none-any.whl (547 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.2.zip (177 kB)
# Collecting six>=1.10
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.0.5-cp36-cp36m-manylinux1_x86_64.whl (10.1 MB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.4.0.tar.gz (15 kB)
# Collecting cloudpickle>=1.1.0
#   Downloading cloudpickle-1.5.0-py3-none-any.whl (22 kB)
# Collecting dotnetcore2>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting azureml-dataprep-native<15.0.0,>=14.2.1
#   Downloading azureml_dataprep_native-14.2.1-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Collecting fusepy>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.9.0->azureml-defaults->-r /azureml-environment-setup/condaenv.zdj6ybrd.requirements.txt (line 2)) (2020.6.20)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.7.0-py2.py3-none-any.whl (121 kB)
# Collecting msal-extensions~=0.1.3
#   Downloading msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Downloading msal-1.4.1-py2.py3-none-any.whl (48 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: json-logging-py, dill, liac-arff, fusepy
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=9af9e3dc987f7fb1e6e59fac4a03ec8147a1b6b6cb9025f454cdf4a3b226d6b4
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=0c830643cc3610252d62b999c31bae3c5ffb93fcab415a1081b95a168669ced1
#   Stored in directory: /root/.cache/pip/wheels/02/49/cf/660924cd9bc5fcddc3a0246fe39800c83028d3ccea244de352
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-py3-none-any.whl size=13333 sha256=8f3eb586fe993d18df10f5bd006fa0b0a8651b3b64bc1ff32c53e54210b4e7fa
#   Stored in directory: /root/.cache/pip/wheels/ba/2a/e1/6f7be2e2ea150e2486bff64fd6f0670f4f35f4c8f31c819fb8
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=750858b8d637bb04d283950a123f07ef67899dc1d92267843a24361eb30fffa6
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built json-logging-py dill liac-arff fusepy
# Installing collected packages: joblib, werkzeug, MarkupSafe, Jinja2, click, itsdangerous, flask, six, pycparser, cffi, cryptography, jeepney, SecretStorage, websocket-client, urllib3, chardet, idna, requests, docker, azure-common, oauthlib, requests-oauthlib, isodate, msrest, PyJWT, python-dateutil, adal, msrestazure, azure-mgmt-resource, backports.weakref, backports.tempfile, azure-mgmt-authorization, azure-mgmt-keyvault, azure-graphrbac, pyasn1, pyopenssl, ndg-httpsclient, zipp, importlib-metadata, jsonpickle, azure-mgmt-containerregistry, pytz, pathspec, jmespath, ruamel.yaml.clib, ruamel.yaml, contextlib2, azure-mgmt-network, azure-mgmt-storage, azureml-core, applicationinsights, dill, numpy, pandas, liac-arff, azureml-model-management-sdk, cloudpickle, distro, dotnetcore2, azureml-dataprep-native, azure-core, msal, portalocker, msal-extensions, azure-identity, fusepy, azureml-dataprep, configparser, json-logging-py, gunicorn, azureml-defaults, scipy, scikit-learn
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.4 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.7.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-network-10.2.0 azure-mgmt-resource-10.1.0 azure-mgmt-storage-11.1.0 azureml-core-1.9.0 azureml-dataprep-1.9.3 azureml-dataprep-native-14.2.1 azureml-defaults-1.9.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.0 chardet-3.0.4 click-7.1.2 cloudpickle-1.5.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-2.9.2 dill-0.3.2 distro-1.5.0 docker-4.2.2 dotnetcore2-2.1.14 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-1.7.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.10.0 joblib-0.13.2 json-logging-py-0.2 jsonpickle-1.4.1 liac-arff-2.4.0 msal-1.4.1 msal-extensions-0.1.3 msrest-0.6.17 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.19.0 oauthlib-3.1.0 pandas-1.0.5 pathspec-0.8.0 portalocker-1.7.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 python-dateutil-2.8.1 pytz-2020.1 requests-2.24.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 scikit-learn-0.20.3 scipy-1.2.1 six-1.15.0 urllib3-1.25.9 websocket-client-0.57.0 werkzeug-0.16.1 zipp-3.1.0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 7a035b2b9a56
#  ---> caece94cba55
# Step 9/14 : ENV PATH /azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b/bin:$PATH
#  ---> Running in 72ec6765aa1d
# Removing intermediate container 72ec6765aa1d
#  ---> 8ea46cac42e9
# Step 10/14 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b
#  ---> Running in 1970b3539e83
# Removing intermediate container 1970b3539e83
#  ---> bdbc657b3d8e
# Step 11/14 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b/lib:$LD_LIBRARY_PATH
#  ---> Running in 8eb0116d0199
# Removing intermediate container 8eb0116d0199
#  ---> 0be1075e1c1e
# Step 12/14 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 20c480702445
# Step 13/14 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 4819b97e5690
# Removing intermediate container 4819b97e5690
#  ---> a5b75223c19b
# Step 14/14 : CMD ["bash"]
#  ---> Running in 47cca6fada4f
# Removing intermediate container 47cca6fada4f
#  ---> 93856aa78b1b
# Successfully built 93856aa78b1b
# Successfully tagged mlpractice98dcf28c.azurecr.io/azureml/azureml_0cf266db6beb7180c01b79fda0b048c1:latest
# 2020/07/19 08:12:01 Successfully executed container: acb_step_0
# 2020/07/19 08:12:01 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/07/19 08:12:01 Pushing image: mlpractice98dcf28c.azurecr.io/azureml/azureml_0cf266db6beb7180c01b79fda0b048c1:latest, attempt 1
# The push refers to repository [mlpractice98dcf28c.azurecr.io/azureml/azureml_0cf266db6beb7180c01b79fda0b048c1]
# 0c93ce68f486: Preparing
# 11e8f5ab45ca: Preparing
# a1a9c9ed2927: Preparing
# 4b821431296c: Preparing
# 155e51b56075: Preparing
# 7679c3f1f361: Preparing
# f5aa53607bc1: Preparing
# 07eae5ad8c0b: Preparing
# facf43cddd83: Preparing
# 69a9bdc813b0: Preparing
# 7e2b9752143f: Preparing
# 63a67842a4c7: Preparing
# ae3a847dbd6b: Preparing
# 4ae3adcb66cb: Preparing
# aa6685385151: Preparing
# 0040d8f00d7e: Preparing
# 9e6f810a2aab: Preparing
# 7679c3f1f361: Waiting
# f5aa53607bc1: Waiting
# 07eae5ad8c0b: Waiting
# facf43cddd83: Waiting
# 69a9bdc813b0: Waiting
# 7e2b9752143f: Waiting
# 63a67842a4c7: Waiting
# ae3a847dbd6b: Waiting
# 4ae3adcb66cb: Waiting
# aa6685385151: Waiting
# 0040d8f00d7e: Waiting
# 9e6f810a2aab: Waiting
# 155e51b56075: Pushed
# 4b821431296c: Pushed
# 0c93ce68f486: Pushed
# a1a9c9ed2927: Pushed
# 7679c3f1f361: Pushed
# f5aa53607bc1: Pushed
# 07eae5ad8c0b: Pushed
#
# 63a67842a4c7: Pushed
# facf43cddd83: Pushed
# 7e2b9752143f: Pushed
# 69a9bdc813b0: Pushed
# 4ae3adcb66cb: Pushed
# aa6685385151: Pushed
# 0040d8f00d7e: Pushed
# ae3a847dbd6b: Pushed
# 9e6f810a2aab: Pushed
# 11e8f5ab45ca: Pushed
# latest: digest: sha256:78105c6924c3c0ecdfbf6d6558c2a73699d79600c8d4b92c16b433b43d2e9c53 size: 3883
# 2020/07/19 08:13:14 Successfully pushed image: mlpractice98dcf28c.azurecr.io/azureml/azureml_0cf266db6beb7180c01b79fda0b048c1:latest
# 2020/07/19 08:13:14 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 141.429902)
# 2020/07/19 08:13:14 Populating digests for step ID: acb_step_0...
# 2020/07/19 08:13:16 Successfully populated digests for step ID: acb_step_0
# 2020/07/19 08:13:16 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 73.549865)
# 2020/07/19 08:13:16 The following dependencies were found:
# 2020/07/19 08:13:16
# - image:
#     registry: mlpractice98dcf28c.azurecr.io
#     repository: azureml/azureml_0cf266db6beb7180c01b79fda0b048c1
#     tag: latest
#     digest: sha256:78105c6924c3c0ecdfbf6d6558c2a73699d79600c8d4b92c16b433b43d2e9c53
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200423.v1
#     digest: sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
#   git: {}
#
#
# Run ID: cbc was successful after 3m41s
#
# Streaming azureml-logs/75_job_post-tvmps_6a95c5ef818df04ee92127ba3ba4e82e90db26a97a30705c6c4743ea313ed5d8_d.txt
# ===============================================================================================================
#
# Entering job release. Current time:2020-07-19T08:14:57.899568
# Starting job release. Current time:2020-07-19T08:14:59.292365
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 149
# [2020-07-19T08:14:59.317298] Entering context manager injector.
# Job release is complete. Current time:2020-07-19T08:15:25.867478
#
# Execution Summary
# =================
# RunId: sklearn-iris_1595146164_f6d591a1
# Web View: https://ml.azure.com/experiments/sklearn-iris/runs/sklearn-iris_1595146164_f6d591a1?wsid=/subscriptions/a1839f8e-ad8f-4825-ab97-e9628255f2bb/resourcegroups/azureml/workspaces/ml_practice
#
# Warnings:
# {
#   "error": {
#     "code": "UserError",
#     "severity": null,
#     "message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.",
#     "messageFormat": null,
#     "messageParameters": null,
#     "referenceCode": null,
#     "detailsUri": null,
#     "target": null,
#     "details": [],
#     "innerError": null,
#     "debugInfo": null
#   },
#   "correlation": {
#     "operation": null,
#     "request": "a2c31a3d79acc707"
#   },
#   "environment": "westeurope",
#   "location": "westeurope",
#   "time": "2020-07-19T08:15:57.5617029+00:00",
#   "componentName": "execution-worker"
# }
# ---------------------------------------------------------------------------
# ActivityFailedException                   Traceback (most recent call last)
# <ipython-input-30-53887da715a3> in <module>
#       1 # Submit a run
#       2 run = experiment.submit(estimator)
# ----> 3 run.wait_for_completion(show_output=True)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/core/run.py in wait_for_completion(self, show_output, wait_post_processing, raise_on_error)
#     698                     file_handle=sys.stdout,
#     699                     wait_post_processing=wait_post_processing,
# --> 700                     raise_on_error=raise_on_error)
#     701                 return self.get_details()
#     702             except KeyboardInterrupt:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/core/run.py in _stream_run_output(self, file_handle, wait_post_processing, raise_on_error)
#     941                 file_handle.write("\n")
#     942             else:
# --> 943                 raise ActivityFailedException(error_details=json.dumps(error, indent=4))
#     944
#     945         file_handle.write("\n")
#
# ActivityFailedException: ActivityFailedException:
# 	Message: Activity Failed:
# {
#     "error": {
#         "code": "UserError",
#         "message": "User program failed with NameError: name 'null' is not defined",
#         "detailsUri": "https://aka.ms/azureml-known-errors",
#         "details": [],
#         "debugInfo": {
#             "type": "NameError",
#             "message": "name 'null' is not defined",
#             "stackTrace": "  File \"/mnt/batch/tasks/shared/LS_root/jobs/ml_practice/azureml/sklearn-iris_1595146164_f6d591a1/mounts/workspaceblobstore/azureml/sklearn-iris_1595146164_f6d591a1/azureml-setup/context_manager_injector.py\", line 148, in execute_with_context\n    runpy.run_path(sys.argv[0], globals(), run_name=\"__main__\")\n  File \"/azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b/lib/python3.6/runpy.py\", line 263, in run_path\n    pkg_name=pkg_name, script_name=fname)\n  File \"/azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b/lib/python3.6/runpy.py\", line 96, in _run_module_code\n    mod_name, mod_spec, pkg_name, script_name)\n  File \"/azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b/lib/python3.6/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n  File \"train_iris.py\", line 1, in <module>\n    {\"cells\":[{\"cell_type\":\"code\",\"source\":[\"# Modified from https://www.geeksforgeeks.org/multiclass-classification-using-scikit-learn/\\r\\n\",\"\\r\\n\",\"import argparse\\r\\n\",\"import os\\r\\n\",\"from azureml.core import Dataset\\r\\n\",\"# importing necessary libraries\\r\\n\",\"import numpy as np\\r\\n\",\"\\r\\n\",\"from sklearn import datasets\\r\\n\",\"from sklearn.metrics import confusion_matrix\\r\\n\",\"from sklearn.model_selection import train_test_split\\r\\n\",\"\\r\\n\",\"import joblib\\r\\n\",\"\\r\\n\",\"from azureml.core.run import Run\\r\\n\",\"run = Run.get_context()\\r\\n\",\"\\r\\n\",\"\\r\\n\",\"def main():\\r\\n\",\"    parser = argparse.ArgumentParser()\\r\\n\",\"\\r\\n\",\"    parser.add_argument('--kernel', type=str, default='linear',\\r\\n\",\"                        help='Kernel type to be used in the algorithm')\\r\\n\",\"    parser.add_argument('--penalty', type=float, default=1.0,\\r\\n\",\"                        help='Penalty parameter of the error term')\\r\\n\",\"\\r\\n\",\"    args = parser.parse_args()\\r\\n\",\"    run.log('Kernel type', np.str(args.kernel))\\r\\n\",\"    run.log('Penalty', np.float(args.penalty))\\r\\n\",\"\\r\\n\",\"    # loading the iris dataset\\r\\n\",\"    # Getting a dataset\\r\\n\",\"\\r\\n\",\"    dataset_name = 'iris'\\r\\n\",\"\\r\\n\",\"    iris = Dataset.get_by_name(workspace= ws, name=dataset_name) \\r\\n\",\"\\r\\n\",\"    #load a tabularDataset by name\\r\\n\",\"    iris_df = iris.to_pandas_dataframe()\\r\\n\",\"\\r\\n\",\"    # X -> features, y -> label\\r\\n\",\"   \\r\\n\",\"    X = iris_df.iloc[:,:3]\\r\\n\",\"    y = iris_df.iloc[:,4]\\r\\n\",\"\\r\\n\",\"    # dividing X, y into train and test data\\r\\n\",\"    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)\\r\\n\",\"\\r\\n\",\"    # training a linear SVM classifier\\r\\n\",\"    from sklearn.svm import SVC\\r\\n\",\"    svm_model_linear = SVC(kernel=args.kernel, C=args.penalty).fit(X_train, y_train)\\r\\n\",\"    svm_predictions = svm_model_linear.predict(X_test)\\r\\n\",\"\\r\\n\",\"    # model accuracy for X_test\\r\\n\",\"    accuracy = svm_model_linear.score(X_test, y_test)\\r\\n\",\"    print('Accuracy of SVM classifier on test set: {:.2f}'.format(accuracy))\\r\\n\",\"    run.log('Accuracy', np.float(accuracy))\\r\\n\",\"    # creating a confusion matrix\\r\\n\",\"    cm = confusion_matrix(y_test, svm_predictions)\\r\\n\",\"    print(cm)\\r\\n\",\"\\r\\n\",\"    os.makedirs('outputs', exist_ok=True)\\r\\n\",\"    # files saved in the \\\"outputs\\\" folder are automatically uploaded into run history\\r\\n\",\"    joblib.dump(svm_model_linear, 'outputs/model.joblib')\\r\\n\",\"\\r\\n\",\"\\r\\n\",\"if __name__ == '__main__':\\r\\n\",\"    main()\\r\\n\"],\"outputs\":[],\"execution_count\":null,\"metadata\":{}}],\"metadata\":{\"kernelspec\":{\"name\":\"python3-azureml\",\"language\":\"python\",\"display_name\":\"Python 3.6 - AzureML\"},\"language_info\":{\"name\":\"python\",\"version\":\"3.6.9\",\"mimetype\":\"text/x-python\",\"codemirror_mode\":{\"name\":\"ipython\",\"version\":3},\"pygments_lexer\":\"ipython3\",\"nbc ...
#         },
#         "messageParameters": {}
#     },
#     "time": "0001-01-01T00:00:00.000Z"
# }
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Activity Failed:\n{\n    \"error\": {\n        \"code\": \"UserError\",\n        \"message\": \"User program failed with NameError: name 'null' is not defined\",\n        \"detailsUri\": \"https://aka.ms/azureml-known-errors\",\n        \"details\": [],\n        \"debugInfo\": {\n            \"type\": \"NameError\",\n            \"message\": \"name 'null' is not defined\",\n            \"stackTrace\": \"  File \\\"/mnt/batch/tasks/shared/LS_root/jobs/ml_practice/azureml/sklearn-iris_1595146164_f6d591a1/mounts/workspaceblobstore/azureml/sklearn-iris_1595146164_f6d591a1/azureml-setup/context_manager_injector.py\\\", line 148, in execute_with_context\\n    runpy.run_path(sys.argv[0], globals(), run_name=\\\"__main__\\\")\\n  File \\\"/azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b/lib/python3.6/runpy.py\\\", line 263, in run_path\\n    pkg_name=pkg_name, script_name=fname)\\n  File \\\"/azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b/lib/python3.6/runpy.py\\\", line 96, in _run_module_code\\n    mod_name, mod_spec, pkg_name, script_name)\\n  File \\\"/azureml-envs/azureml_618d79f5f9d88bbf887dccf51537da4b/lib/python3.6/runpy.py\\\", line 85, in _run_code\\n    exec(code, run_globals)\\n  File \\\"train_iris.py\\\", line 1, in <module>\\n    {\\\"cells\\\":[{\\\"cell_type\\\":\\\"code\\\",\\\"source\\\":[\\\"# Modified from https://www.geeksforgeeks.org/multiclass-classification-using-scikit-learn/\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"import argparse\\\\r\\\\n\\\",\\\"import os\\\\r\\\\n\\\",\\\"from azureml.core import Dataset\\\\r\\\\n\\\",\\\"# importing necessary libraries\\\\r\\\\n\\\",\\\"import numpy as np\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"from sklearn import datasets\\\\r\\\\n\\\",\\\"from sklearn.metrics import confusion_matrix\\\\r\\\\n\\\",\\\"from sklearn.model_selection import train_test_split\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"import joblib\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"from azureml.core.run import Run\\\\r\\\\n\\\",\\\"run = Run.get_context()\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"def main():\\\\r\\\\n\\\",\\\"    parser = argparse.ArgumentParser()\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"    parser.add_argument('--kernel', type=str, default='linear',\\\\r\\\\n\\\",\\\"                        help='Kernel type to be used in the algorithm')\\\\r\\\\n\\\",\\\"    parser.add_argument('--penalty', type=float, default=1.0,\\\\r\\\\n\\\",\\\"                        help='Penalty parameter of the error term')\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"    args = parser.parse_args()\\\\r\\\\n\\\",\\\"    run.log('Kernel type', np.str(args.kernel))\\\\r\\\\n\\\",\\\"    run.log('Penalty', np.float(args.penalty))\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"    # loading the iris dataset\\\\r\\\\n\\\",\\\"    # Getting a dataset\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"    dataset_name = 'iris'\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"    iris = Dataset.get_by_name(workspace= ws, name=dataset_name) \\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"    #load a tabularDataset by name\\\\r\\\\n\\\",\\\"    iris_df = iris.to_pandas_dataframe()\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"    # X -> features, y -> label\\\\r\\\\n\\\",\\\"   \\\\r\\\\n\\\",\\\"    X = iris_df.iloc[:,:3]\\\\r\\\\n\\\",\\\"    y = iris_df.iloc[:,4]\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"    # dividing X, y into train and test data\\\\r\\\\n\\\",\\\"    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"    # training a linear SVM classifier\\\\r\\\\n\\\",\\\"    from sklearn.svm import SVC\\\\r\\\\n\\\",\\\"    svm_model_linear = SVC(kernel=args.kernel, C=args.penalty).fit(X_train, y_train)\\\\r\\\\n\\\",\\\"    svm_predictions = svm_model_linear.predict(X_test)\\\\r\\\\n\\\",\\\"\\\\r\\\\n\\\",\\\"    # model accuracy for X_test\\\\r\\\\n\\\",\\\"    accuracy = svm_model_linear.score(X_test, y_test)\\\\r\\\\n\\\",\\\"    print('Accuracy of SVM classifier on test set: {:.2f}'.fo ...
#     }
# }

# %%
## Tune Model Hyperparamenters

from azureml.train.hyperdrive.runconfig import HyperDriveRunConfig
from azureml.train.hyperdrive.sampling import RandomParameterSampling
from azureml.train.hyperdrive.run import PrimaryMetricGoal
from azureml.train.hyperdrive.parameter_expressions import choice

param_sampling = RandomParameterSampling({
    "--Kernel": choice('linear', 'rbf', 'poly', 'sigmoid'),
    "--penalty": choice(0.5,1, 1.5)
})

hyperdrive_run_config = HyperDriveRunConfig(estimator=estimator, 
                                            hyperparameter_sampling = param_sampling,
                                            primary_metric_goal = PrimaryMetricGoal.MAXIMIZE,
                                            max_total_runs = 12,
                                            max_concurrent_runs = 4)

# %%
# Start the HyperDrive run
hyperdrive_run = experiment.submit(hyperdrive_run_config)
