# %% [markdown]
# ### Author : Kubam Ivo
# ### Date : 7/18/2020

# %%
#Checking SDK version
import azureml.core
from azureml.core import Workspace

print("Azure Ml sdk version: ", azureml.core.VERSION)
# Out:
# Azure Ml sdk version:  1.9.0

# %%
# Initialise workspace
ws = Workspace.from_config()
print('Workspace name: ' + ws.name,
    'Azure region: ' + ws.location,
    'Subscription id: ' + ws.subscription_id,
    'Resource group: ' + ws.resource_group, sep= '\n')
# Out:
# Workspace name: ml_practice
# Azure region: westeurope
# Subscription id: a1839f8e-ad8f-4825-ab97-e9628255f2bb
# Resource group: azureml

# %%
# Create an Experiment
from azureml.core import Experiment

exp =  Experiment(workspace=ws, name='estimator-test')

# %%
# using existing cluster
from azureml.core.compute import ComputeTarget, AmlCompute
cluster_name = 'mlcompute'
cpu_cluster = ComputeTarget(workspace=ws, name=cluster_name)
print(cpu_cluster.get_status().serialize())
# Out:
# {'currentNodeCount': 0, 'targetNodeCount': 0, 'nodeStateCounts': {'preparingNodeCount': 0, 'runningNodeCount': 0, 'idleNodeCount': 0, 'unusableNodeCount': 0, 'leavingNodeCount': 0, 'preemptedNodeCount': 0}, 'allocationState': 'Steady', 'allocationStateTransitionTime': '2020-07-16T16:56:15.815000+00:00', 'errors': None, 'creationTime': '2020-07-14T14:30:21.544981+00:00', 'modifiedTime': '2020-07-16T20:55:17.320527+00:00', 'provisioningState': 'Succeeded', 'provisioningStateTransitionTime': None, 'scaleSettings': {'minNodeCount': 0, 'maxNodeCount': 1, 'nodeIdleTimeBeforeScaleDown': 'PT120S'}, 'vmPriority': 'Dedicated', 'vmSize': 'STANDARD_DS2_V2'}

# %%
compute_targets = ws.compute_targets
for name, ct in compute_targets.items():
    print(name, ct.type, ct.provisioning_state)
# Out:
# seedml ComputeInstance Succeeded
# mlcompute AmlCompute Succeeded

# %%
# Create a generic Estimator
from azureml.train.estimator import Estimator
from azureml.widgets import RunDetails
est = Estimator(source_directory= '.',
                compute_target = cluster_name,
                entry_script = 'train.py',
                
                conda_packages = ['scikit-learn'])

# Running the experiment
run = exp.submit(est)
RunDetails(run).show()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…
